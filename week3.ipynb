# %% [markdown]
# #

# %%
import torch
import matplotlib.pyplot as plt

# %%
x= torch.tensor([13.4,14.3,14.5,16.1,16.9,16.5,15.4,17.0,17.9,18.8,20.3,22.4,19.4,15.5,16.7,17.3,18.4,19.2,17.4,19.5,19.7,21.2])

# %%
y= torch.tensor([11.2,12.5,12.7,13.1,14.1,14.8,14.4,13.4,14.9,15.6,16.4,17.7,19.6,16.9,14.0,14.6,15.1,16.1,16.8,15.2,17.0,17.2,18.6])

# %%
b=torch.rand([1], requires_grad=True)
w=torch.rand([1], requires_grad=True)
print("The parameters are {} and {}".format(w,b))
# Out:
# The parameters are tensor([0.2521], requires_grad=True) and tensor([0.6442], requires_grad=True)

# %%
learning_rate=torch.tensor(0.001)
loss_list = []

# %%
for epochs in range(100):
    loss = 0.0
    for j in range(len(x)):
        a = w*x[j]
        y_p = a+b
        loss+= (y_p-y[j])**2
    loss = loss/len(x)
    loss_list.append(loss.item())
    loss.backward()
    with torch.no_grad():
        w -= learning_rate*w.grad
        b -= learning_rate*b.grad
    w.grad.zero_()
    b.grad.zero_()
    print("The parameters are w={}, b={} and loss = {}".format(w,b,loss.item()))
plt.plot(loss_list)
plt.show()
# Out:
# The parameters are w=tensor([0.6110], requires_grad=True), b=tensor([0.6643], requires_grad=True) and loss = 103.60566711425781
# The parameters are w=tensor([0.7425], requires_grad=True), b=tensor([0.6717], requires_grad=True) and loss = 15.315729141235352
# The parameters are w=tensor([0.7907], requires_grad=True), b=tensor([0.6745], requires_grad=True) and loss = 3.4617486000061035
# The parameters are w=tensor([0.8083], requires_grad=True), b=tensor([0.6756], requires_grad=True) and loss = 1.870204210281372
# The parameters are w=tensor([0.8148], requires_grad=True), b=tensor([0.6760], requires_grad=True) and loss = 1.6565135717391968
# The parameters are w=tensor([0.8172], requires_grad=True), b=tensor([0.6762], requires_grad=True) and loss = 1.6278157234191895
# The parameters are w=tensor([0.8180], requires_grad=True), b=tensor([0.6764], requires_grad=True) and loss = 1.6239548921585083
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6765], requires_grad=True) and loss = 1.6234294176101685
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6766], requires_grad=True) and loss = 1.6233519315719604
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6767], requires_grad=True) and loss = 1.6233344078063965
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6768], requires_grad=True) and loss = 1.6233253479003906
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6769], requires_grad=True) and loss = 1.6233168840408325
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6770], requires_grad=True) and loss = 1.6233081817626953
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6770], requires_grad=True) and loss = 1.6233004331588745
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6771], requires_grad=True) and loss = 1.623292088508606
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6772], requires_grad=True) and loss = 1.623283863067627
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6773], requires_grad=True) and loss = 1.623275876045227
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6774], requires_grad=True) and loss = 1.6232672929763794
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6775], requires_grad=True) and loss = 1.6232587099075317
# The parameters are w=tensor([0.8185], requires_grad=True), b=tensor([0.6776], requires_grad=True) and loss = 1.6232506036758423
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6777], requires_grad=True) and loss = 1.6232421398162842
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6778], requires_grad=True) and loss = 1.6232339143753052
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6779], requires_grad=True) and loss = 1.6232258081436157
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6780], requires_grad=True) and loss = 1.6232178211212158
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6780], requires_grad=True) and loss = 1.6232094764709473
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6781], requires_grad=True) and loss = 1.6232013702392578
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6782], requires_grad=True) and loss = 1.6231929063796997
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6783], requires_grad=True) and loss = 1.6231849193572998
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6784], requires_grad=True) and loss = 1.6231765747070312
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6785], requires_grad=True) and loss = 1.623167872428894
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6786], requires_grad=True) and loss = 1.6231598854064941
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6787], requires_grad=True) and loss = 1.6231513023376465
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6788], requires_grad=True) and loss = 1.6231426000595093
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6789], requires_grad=True) and loss = 1.6231350898742676
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6790], requires_grad=True) and loss = 1.6231261491775513
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6790], requires_grad=True) and loss = 1.6231192350387573
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6791], requires_grad=True) and loss = 1.6231106519699097
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6792], requires_grad=True) and loss = 1.623102068901062
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6793], requires_grad=True) and loss = 1.623093843460083
# The parameters are w=tensor([0.8184], requires_grad=True), b=tensor([0.6794], requires_grad=True) and loss = 1.6230860948562622
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6795], requires_grad=True) and loss = 1.6230772733688354
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6796], requires_grad=True) and loss = 1.623069405555725
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6797], requires_grad=True) and loss = 1.6230610609054565
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6798], requires_grad=True) and loss = 1.623052716255188
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6799], requires_grad=True) and loss = 1.6230442523956299
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6799], requires_grad=True) and loss = 1.6230366230010986
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6800], requires_grad=True) and loss = 1.6230276823043823
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6801], requires_grad=True) and loss = 1.6230202913284302
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6802], requires_grad=True) and loss = 1.6230114698410034
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6803], requires_grad=True) and loss = 1.6230037212371826
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6804], requires_grad=True) and loss = 1.6229950189590454
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6805], requires_grad=True) and loss = 1.6229866743087769
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6806], requires_grad=True) and loss = 1.6229783296585083
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6807], requires_grad=True) and loss = 1.6229705810546875
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6808], requires_grad=True) and loss = 1.6229615211486816
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6809], requires_grad=True) and loss = 1.622954249382019
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6809], requires_grad=True) and loss = 1.6229456663131714
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6810], requires_grad=True) and loss = 1.622937798500061
# The parameters are w=tensor([0.8183], requires_grad=True), b=tensor([0.6811], requires_grad=True) and loss = 1.6229296922683716
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6812], requires_grad=True) and loss = 1.622921109199524
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6813], requires_grad=True) and loss = 1.6229126453399658
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6814], requires_grad=True) and loss = 1.6229050159454346
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6815], requires_grad=True) and loss = 1.6228965520858765
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6816], requires_grad=True) and loss = 1.6228878498077393
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6817], requires_grad=True) and loss = 1.6228801012039185
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6818], requires_grad=True) and loss = 1.6228715181350708
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6819], requires_grad=True) and loss = 1.6228630542755127
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6819], requires_grad=True) and loss = 1.6228556632995605
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6820], requires_grad=True) and loss = 1.622847318649292
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6821], requires_grad=True) and loss = 1.622839331626892
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6822], requires_grad=True) and loss = 1.6228305101394653
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6823], requires_grad=True) and loss = 1.6228222846984863
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6824], requires_grad=True) and loss = 1.6228141784667969
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6825], requires_grad=True) and loss = 1.622806191444397
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6826], requires_grad=True) and loss = 1.6227977275848389
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6827], requires_grad=True) and loss = 1.6227893829345703
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6828], requires_grad=True) and loss = 1.6227812767028809
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6828], requires_grad=True) and loss = 1.6227726936340332
# The parameters are w=tensor([0.8182], requires_grad=True), b=tensor([0.6829], requires_grad=True) and loss = 1.6227656602859497
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6830], requires_grad=True) and loss = 1.6227573156356812
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6831], requires_grad=True) and loss = 1.622748613357544
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6832], requires_grad=True) and loss = 1.6227401494979858
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6833], requires_grad=True) and loss = 1.6227320432662964
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6834], requires_grad=True) and loss = 1.6227240562438965
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6835], requires_grad=True) and loss = 1.6227154731750488
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6836], requires_grad=True) and loss = 1.6227073669433594
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6837], requires_grad=True) and loss = 1.6226990222930908
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6838], requires_grad=True) and loss = 1.6226913928985596
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6838], requires_grad=True) and loss = 1.6226824522018433
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6839], requires_grad=True) and loss = 1.6226749420166016
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6840], requires_grad=True) and loss = 1.622666597366333
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6841], requires_grad=True) and loss = 1.6226576566696167
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6842], requires_grad=True) and loss = 1.6226505041122437
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6843], requires_grad=True) and loss = 1.6226418018341064
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6844], requires_grad=True) and loss = 1.6226330995559692
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6845], requires_grad=True) and loss = 1.6226252317428589
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6846], requires_grad=True) and loss = 1.622617244720459
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6847], requires_grad=True) and loss = 1.6226086616516113
# The parameters are w=tensor([0.8181], requires_grad=True), b=tensor([0.6847], requires_grad=True) and loss = 1.6226006746292114
# The parameters are w=tensor([0.8180], requires_grad=True), b=tensor([0.6848], requires_grad=True) and loss = 1.6225924491882324

# %%
#Q1

# %%
x=torch.tensor([12.4,14.3,14.5,14.9,16.1,16.9,16.5,15.4,17.0,17.9,18.8,20.3,22.4,19.4,15.5,16.7,17.3,18.4,19.2,17.4,19.5,19.7,21.2])
y=torch.tensor([11.2,12.5,12.7,13.1,14.1,14.8,14.4,13.4,14.9,15.6,16.4,17.7,19.6,16.9,14.0,14.6,15.1,16.1,16.8,15.2,17.0,17.2,18.6])

# %%
b=torch.rand([1], requires_grad=True)
w=torch.rand([1], requires_grad=True)
print("The parameters are {} and {}".format(w,b))
# Out:
# The parameters are tensor([0.6215], requires_grad=True) and tensor([0.2792], requires_grad=True)

# %%
learning_rate=torch.tensor(0.001)
loss_list = []

# %%
for epochs in range(100):
    loss = 0.0
    for j in range(len(x)):
        a = w*x[j]
        y_p = a+b
        loss+= (y_p-y[j])**2
    loss = loss/len(x)
    loss_list.append(loss.item())
    loss.backward()
    with torch.no_grad():
        w -= learning_rate*w.grad
        b -= learning_rate*b.grad
    w.grad.zero_()
    b.grad.zero_()
    print("The parameters are w={}, b={} and loss = {}".format(w,b,loss.item()))
plt.plot(loss_list)
plt.show()
# Out:
# The parameters are w=tensor([0.7696], requires_grad=True), b=tensor([0.2875], requires_grad=True) and loss = 17.65768051147461
# The parameters are w=tensor([0.8254], requires_grad=True), b=tensor([0.2907], requires_grad=True) and loss = 2.5177299976348877
# The parameters are w=tensor([0.8464], requires_grad=True), b=tensor([0.2918], requires_grad=True) and loss = 0.3679482042789459
# The parameters are w=tensor([0.8543], requires_grad=True), b=tensor([0.2923], requires_grad=True) and loss = 0.06269179284572601
# The parameters are w=tensor([0.8573], requires_grad=True), b=tensor([0.2925], requires_grad=True) and loss = 0.01934722624719143
# The parameters are w=tensor([0.8584], requires_grad=True), b=tensor([0.2925], requires_grad=True) and loss = 0.013192526996135712
# The parameters are w=tensor([0.8589], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012318557128310204
# The parameters are w=tensor([0.8590], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012194451875984669
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012176776304841042
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.01217428594827652
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173866853117943
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173808179795742
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.01217377558350563
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173768132925034
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173719704151154
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173713184893131
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173675000667572
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.0121736666187644
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2926], requires_grad=True) and loss = 0.012173577211797237
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173587456345558
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173551134765148
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.01217354740947485
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.01217350922524929
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.0121734868735075
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.01217343658208847
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173428200185299
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173403985798359
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173378840088844
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173380702733994
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173322029411793
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173322029411793
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173274531960487
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173234485089779
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173238210380077
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.01217319630086422
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173191644251347
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173148803412914
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173132039606571
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2927], requires_grad=True) and loss = 0.012173098511993885
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.01217304915189743
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012173033319413662
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012173027731478214
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172997929155827
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172983959317207
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172968126833439
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172884307801723
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172904796898365
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172870337963104
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172847986221313
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172838672995567
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172823771834373
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172757647931576
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.01217271201312542
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172705493867397
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172682210803032
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.01217265147715807
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172657065093517
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.012172622606158257
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2928], requires_grad=True) and loss = 0.01217256672680378
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172555550932884
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172535993158817
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172510847449303
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172502465546131
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172456830739975
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172408401966095
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172372080385685
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172367423772812
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172340415418148
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.01217231061309576
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172331102192402
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172272428870201
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172232381999493
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172224931418896
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172186747193336
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172184884548187
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172168120741844
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.012172139249742031
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.01217211689800024
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2929], requires_grad=True) and loss = 0.01217202004045248
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012172017246484756
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012172004207968712
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171982787549496
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.0121719716116786
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171941809356213
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171940878033638
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171880342066288
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171860784292221
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171854265034199
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171820737421513
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171789072453976
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171761132776737
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171695940196514
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171688489615917
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171676382422447
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171653099358082
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171654962003231
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.01217161025851965
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2930], requires_grad=True) and loss = 0.012171599082648754
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2931], requires_grad=True) and loss = 0.012171552516520023
# The parameters are w=tensor([0.8591], requires_grad=True), b=tensor([0.2931], requires_grad=True) and loss = 0.012171506881713867

# %%
#Q2

# %%
x=torch.tensor([2,4])
y=torch.tensor([20,40])

# %%
b=torch.tensor(1.0, requires_grad=True)
w=torch.tensor(1.0, requires_grad=True)
print("The parameters are {} and {}".format(w,b))
# Out:
# The parameters are 1.0 and 1.0

# %%
learning_rate=torch.tensor(0.001)
loss_list = []

# %%
for epochs in range(2):
    loss = 0.0
    for j in range(len(x)):
        a = w*x[j]
        y_p = a+b
        loss+= (y_p-y[j])**2
    loss = loss/len(x)
    loss_list.append(loss.item())
    loss.backward()
    with torch.no_grad():
        w -= learning_rate*w.grad
        b -= learning_rate*b.gradimport torch

    print(f"W grad is {w.grad}\nb grad is {b.grad}\n")
    w.grad.zero_()
    b.grad.zero_()
    print("The parameters are w={}, b={} and loss = {}\n".format(w,b,loss.item()))
plt.plot(loss_list)
plt.show()
# Out:
# W grad is -174.0
# b grad is -52.0
#
# The parameters are w=1.1740000247955322, b=1.0520000457763672 and loss = 757.0
#
# W grad is -170.20799255371094
# b grad is -50.85199737548828
#
# The parameters are w=1.344208002090454, b=1.1028521060943604 and loss = 724.3797607421875

# %%
class RegressionModel:
    def __init__(self):
        self.w = torch.rand([1], requires_grad=True)
        self.b = torch.rand([1], requires_grad=True)
    def forward(self, x):
        return self.w*x+self.b
    def update(self):
        self.w -= learning_rate * self.w.grad
        self.b -= learning_rate*self.b.grad
    def reset_grad(self):
        self.w.grad.zero_()
        self.b.grad.zero_()

# %%
def criterion(yj,y_p):
        return (yj- y_p)**2
x=torch.tensor([5.0,7.0,12.0,16.0,20.0])
y=torch.tensor([40.0,120.0,180.0,210.0,240.0])
model = RegressionModel()
loss_list = []
for epochs in range(100):
    loss = 0.0
    for j in range(len(x)):
        y_p = model.forward(x[j])
        loss += criterion(y[j], y_p)
    loss = loss/len(x)
    loss_list.append(loss.item())
    loss.backward()
    with torch.no_grad():
        model.update()
    model.reset_grad()
    print("The parameters are w={}, b={} and loss={}".format(model.w,model.b,loss.item()))
plt.plot(loss_list)
plt.show()
# Out:
# The parameters are w=tensor([5.0778], requires_grad=True), b=tensor([0.9648], requires_grad=True) and loss=26105.130859375
# The parameters are w=tensor([7.8235], requires_grad=True), b=tensor([1.1570], requires_grad=True) and loss=11267.0654296875
# The parameters are w=tensor([9.6046], requires_grad=True), b=tensor([1.2829], requires_grad=True) and loss=5022.05078125
# The parameters are w=tensor([10.7601], requires_grad=True), b=tensor([1.3659], requires_grad=True) and loss=2393.65869140625
# The parameters are w=tensor([11.5096], requires_grad=True), b=tensor([1.4209], requires_grad=True) and loss=1287.419189453125
# The parameters are w=tensor([11.9957], requires_grad=True), b=tensor([1.4578], requires_grad=True) and loss=821.8214111328125
# The parameters are w=tensor([12.3110], requires_grad=True), b=tensor([1.4830], requires_grad=True) and loss=625.8545532226562
# The parameters are w=tensor([12.5155], requires_grad=True), b=tensor([1.5006], requires_grad=True) and loss=543.3692016601562
# The parameters are w=tensor([12.6481], requires_grad=True), b=tensor([1.5132], requires_grad=True) and loss=508.6458435058594
# The parameters are w=tensor([12.7340], requires_grad=True), b=tensor([1.5226], requires_grad=True) and loss=494.02435302734375
# The parameters are w=tensor([12.7896], requires_grad=True), b=tensor([1.5300], requires_grad=True) and loss=487.86370849609375
# The parameters are w=tensor([12.8257], requires_grad=True), b=tensor([1.5360], requires_grad=True) and loss=485.263671875
# The parameters are w=tensor([12.8489], requires_grad=True), b=tensor([1.5411], requires_grad=True) and loss=484.16192626953125
# The parameters are w=tensor([12.8640], requires_grad=True), b=tensor([1.5456], requires_grad=True) and loss=483.69140625
# The parameters are w=tensor([12.8736], requires_grad=True), b=tensor([1.5498], requires_grad=True) and loss=483.48614501953125
# The parameters are w=tensor([12.8798], requires_grad=True), b=tensor([1.5537], requires_grad=True) and loss=483.3924865722656
# The parameters are w=tensor([12.8837], requires_grad=True), b=tensor([1.5575], requires_grad=True) and loss=483.34625244140625
# The parameters are w=tensor([12.8862], requires_grad=True), b=tensor([1.5612], requires_grad=True) and loss=483.319580078125
# The parameters are w=tensor([12.8877], requires_grad=True), b=tensor([1.5648], requires_grad=True) and loss=483.3011779785156
# The parameters are w=tensor([12.8886], requires_grad=True), b=tensor([1.5683], requires_grad=True) and loss=483.2867736816406
# The parameters are w=tensor([12.8891], requires_grad=True), b=tensor([1.5719], requires_grad=True) and loss=483.2735290527344
# The parameters are w=tensor([12.8894], requires_grad=True), b=tensor([1.5754], requires_grad=True) and loss=483.2605895996094
# The parameters are w=tensor([12.8894], requires_grad=True), b=tensor([1.5789], requires_grad=True) and loss=483.24859619140625
# The parameters are w=tensor([12.8894], requires_grad=True), b=tensor([1.5824], requires_grad=True) and loss=483.2362365722656
# The parameters are w=tensor([12.8893], requires_grad=True), b=tensor([1.5859], requires_grad=True) and loss=483.223876953125
# The parameters are w=tensor([12.8891], requires_grad=True), b=tensor([1.5894], requires_grad=True) and loss=483.21142578125
# The parameters are w=tensor([12.8889], requires_grad=True), b=tensor([1.5929], requires_grad=True) and loss=483.19976806640625
# The parameters are w=tensor([12.8887], requires_grad=True), b=tensor([1.5963], requires_grad=True) and loss=483.187255859375
# The parameters are w=tensor([12.8885], requires_grad=True), b=tensor([1.5998], requires_grad=True) and loss=483.1751403808594
# The parameters are w=tensor([12.8883], requires_grad=True), b=tensor([1.6033], requires_grad=True) and loss=483.163330078125
# The parameters are w=tensor([12.8881], requires_grad=True), b=tensor([1.6068], requires_grad=True) and loss=483.15106201171875
# The parameters are w=tensor([12.8878], requires_grad=True), b=tensor([1.6102], requires_grad=True) and loss=483.13873291015625
# The parameters are w=tensor([12.8876], requires_grad=True), b=tensor([1.6137], requires_grad=True) and loss=483.12640380859375
# The parameters are w=tensor([12.8874], requires_grad=True), b=tensor([1.6172], requires_grad=True) and loss=483.1145935058594
# The parameters are w=tensor([12.8871], requires_grad=True), b=tensor([1.6206], requires_grad=True) and loss=483.1023864746094
# The parameters are w=tensor([12.8869], requires_grad=True), b=tensor([1.6241], requires_grad=True) and loss=483.09002685546875
# The parameters are w=tensor([12.8867], requires_grad=True), b=tensor([1.6276], requires_grad=True) and loss=483.078369140625
# The parameters are w=tensor([12.8864], requires_grad=True), b=tensor([1.6310], requires_grad=True) and loss=483.06634521484375
# The parameters are w=tensor([12.8862], requires_grad=True), b=tensor([1.6345], requires_grad=True) and loss=483.0541076660156
# The parameters are w=tensor([12.8859], requires_grad=True), b=tensor([1.6380], requires_grad=True) and loss=483.04241943359375
# The parameters are w=tensor([12.8857], requires_grad=True), b=tensor([1.6414], requires_grad=True) and loss=483.030029296875
# The parameters are w=tensor([12.8855], requires_grad=True), b=tensor([1.6449], requires_grad=True) and loss=483.01837158203125
# The parameters are w=tensor([12.8852], requires_grad=True), b=tensor([1.6484], requires_grad=True) and loss=483.00579833984375
# The parameters are w=tensor([12.8850], requires_grad=True), b=tensor([1.6518], requires_grad=True) and loss=482.99407958984375
# The parameters are w=tensor([12.8848], requires_grad=True), b=tensor([1.6553], requires_grad=True) and loss=482.98211669921875
# The parameters are w=tensor([12.8845], requires_grad=True), b=tensor([1.6587], requires_grad=True) and loss=482.9698791503906
# The parameters are w=tensor([12.8843], requires_grad=True), b=tensor([1.6622], requires_grad=True) and loss=482.9581604003906
# The parameters are w=tensor([12.8840], requires_grad=True), b=tensor([1.6656], requires_grad=True) and loss=482.9459533691406
# The parameters are w=tensor([12.8838], requires_grad=True), b=tensor([1.6691], requires_grad=True) and loss=482.93408203125
# The parameters are w=tensor([12.8836], requires_grad=True), b=tensor([1.6725], requires_grad=True) and loss=482.9219665527344
# The parameters are w=tensor([12.8833], requires_grad=True), b=tensor([1.6760], requires_grad=True) and loss=482.9102478027344
# The parameters are w=tensor([12.8831], requires_grad=True), b=tensor([1.6794], requires_grad=True) and loss=482.8980407714844
# The parameters are w=tensor([12.8829], requires_grad=True), b=tensor([1.6829], requires_grad=True) and loss=482.8861389160156
# The parameters are w=tensor([12.8826], requires_grad=True), b=tensor([1.6863], requires_grad=True) and loss=482.87396240234375
# The parameters are w=tensor([12.8824], requires_grad=True), b=tensor([1.6898], requires_grad=True) and loss=482.86199951171875
# The parameters are w=tensor([12.8822], requires_grad=True), b=tensor([1.6932], requires_grad=True) and loss=482.85009765625
# The parameters are w=tensor([12.8819], requires_grad=True), b=tensor([1.6967], requires_grad=True) and loss=482.83831787109375
# The parameters are w=tensor([12.8817], requires_grad=True), b=tensor([1.7001], requires_grad=True) and loss=482.826416015625
# The parameters are w=tensor([12.8814], requires_grad=True), b=tensor([1.7035], requires_grad=True) and loss=482.814697265625
# The parameters are w=tensor([12.8812], requires_grad=True), b=tensor([1.7070], requires_grad=True) and loss=482.80255126953125
# The parameters are w=tensor([12.8810], requires_grad=True), b=tensor([1.7104], requires_grad=True) and loss=482.790771484375
# The parameters are w=tensor([12.8807], requires_grad=True), b=tensor([1.7138], requires_grad=True) and loss=482.77899169921875
# The parameters are w=tensor([12.8805], requires_grad=True), b=tensor([1.7173], requires_grad=True) and loss=482.76702880859375
# The parameters are w=tensor([12.8803], requires_grad=True), b=tensor([1.7207], requires_grad=True) and loss=482.75537109375
# The parameters are w=tensor([12.8800], requires_grad=True), b=tensor([1.7241], requires_grad=True) and loss=482.743408203125
# The parameters are w=tensor([12.8798], requires_grad=True), b=tensor([1.7276], requires_grad=True) and loss=482.73162841796875
# The parameters are w=tensor([12.8796], requires_grad=True), b=tensor([1.7310], requires_grad=True) and loss=482.7198791503906
# The parameters are w=tensor([12.8793], requires_grad=True), b=tensor([1.7344], requires_grad=True) and loss=482.7083435058594
# The parameters are w=tensor([12.8791], requires_grad=True), b=tensor([1.7379], requires_grad=True) and loss=482.6961364746094
# The parameters are w=tensor([12.8788], requires_grad=True), b=tensor([1.7413], requires_grad=True) and loss=482.6844177246094
# The parameters are w=tensor([12.8786], requires_grad=True), b=tensor([1.7447], requires_grad=True) and loss=482.67279052734375
# The parameters are w=tensor([12.8784], requires_grad=True), b=tensor([1.7481], requires_grad=True) and loss=482.6607971191406
# The parameters are w=tensor([12.8781], requires_grad=True), b=tensor([1.7516], requires_grad=True) and loss=482.6490783691406
# The parameters are w=tensor([12.8779], requires_grad=True), b=tensor([1.7550], requires_grad=True) and loss=482.6375427246094
# The parameters are w=tensor([12.8777], requires_grad=True), b=tensor([1.7584], requires_grad=True) and loss=482.625732421875
# The parameters are w=tensor([12.8774], requires_grad=True), b=tensor([1.7618], requires_grad=True) and loss=482.6136779785156
# The parameters are w=tensor([12.8772], requires_grad=True), b=tensor([1.7652], requires_grad=True) and loss=482.60198974609375
# The parameters are w=tensor([12.8770], requires_grad=True), b=tensor([1.7687], requires_grad=True) and loss=482.5902404785156
# The parameters are w=tensor([12.8767], requires_grad=True), b=tensor([1.7721], requires_grad=True) and loss=482.578369140625
# The parameters are w=tensor([12.8765], requires_grad=True), b=tensor([1.7755], requires_grad=True) and loss=482.5668029785156
# The parameters are w=tensor([12.8763], requires_grad=True), b=tensor([1.7789], requires_grad=True) and loss=482.55523681640625
# The parameters are w=tensor([12.8760], requires_grad=True), b=tensor([1.7823], requires_grad=True) and loss=482.54345703125
# The parameters are w=tensor([12.8758], requires_grad=True), b=tensor([1.7857], requires_grad=True) and loss=482.5318908691406
# The parameters are w=tensor([12.8756], requires_grad=True), b=tensor([1.7891], requires_grad=True) and loss=482.5199279785156
# The parameters are w=tensor([12.8753], requires_grad=True), b=tensor([1.7925], requires_grad=True) and loss=482.50823974609375
# The parameters are w=tensor([12.8751], requires_grad=True), b=tensor([1.7959], requires_grad=True) and loss=482.49652099609375
# The parameters are w=tensor([12.8749], requires_grad=True), b=tensor([1.7994], requires_grad=True) and loss=482.4853515625
# The parameters are w=tensor([12.8746], requires_grad=True), b=tensor([1.8028], requires_grad=True) and loss=482.47344970703125
# The parameters are w=tensor([12.8744], requires_grad=True), b=tensor([1.8062], requires_grad=True) and loss=482.46197509765625
# The parameters are w=tensor([12.8742], requires_grad=True), b=tensor([1.8096], requires_grad=True) and loss=482.45037841796875
# The parameters are w=tensor([12.8739], requires_grad=True), b=tensor([1.8130], requires_grad=True) and loss=482.438720703125
# The parameters are w=tensor([12.8737], requires_grad=True), b=tensor([1.8164], requires_grad=True) and loss=482.4267578125
# The parameters are w=tensor([12.8735], requires_grad=True), b=tensor([1.8198], requires_grad=True) and loss=482.41534423828125
# The parameters are w=tensor([12.8732], requires_grad=True), b=tensor([1.8232], requires_grad=True) and loss=482.40350341796875
# The parameters are w=tensor([12.8730], requires_grad=True), b=tensor([1.8266], requires_grad=True) and loss=482.39190673828125
# The parameters are w=tensor([12.8728], requires_grad=True), b=tensor([1.8300], requires_grad=True) and loss=482.380615234375
# The parameters are w=tensor([12.8725], requires_grad=True), b=tensor([1.8333], requires_grad=True) and loss=482.36895751953125
# The parameters are w=tensor([12.8723], requires_grad=True), b=tensor([1.8367], requires_grad=True) and loss=482.3572692871094
# The parameters are w=tensor([12.8721], requires_grad=True), b=tensor([1.8401], requires_grad=True) and loss=482.3458557128906
# The parameters are w=tensor([12.8718], requires_grad=True), b=tensor([1.8435], requires_grad=True) and loss=482.33404541015625

# %%
#Q4
import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self,idx):
        return self.X[idx],self.Y[idx]

x = torch.tensor([1,5,10,10,25,50,70,75,100])
y = torch.tensor([0,0,0,0,0,1,1,1,1])
dataset = MyDataset(x,y)
data_loader = DataLoader(dataset,batch_size=1,shuffle=False)

class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x):
        return self.w*x + self.b

loss_fn = torch.nn.BCELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001)

for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        inputs,labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        sigmoid = torch.nn.Sigmoid()
        outputs = sigmoid(outputs)
        labels = labels.to(torch.float32)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
        loss += loss.item()

    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))

    finalloss = loss/len(data_loader)*4

print(finalloss)
# Out:
# After 0 epochs, The parameters are w=Parameter containing:
# tensor([0.8160], requires_grad=True),b=Parameter containing:
# tensor([0.0300], requires_grad=True), and loss =0.0
# After 10 epochs, The parameters are w=Parameter containing:
# tensor([0.4366], requires_grad=True),b=Parameter containing:
# tensor([-0.0112], requires_grad=True), and loss =0.0
# After 20 epochs, The parameters are w=Parameter containing:
# tensor([0.0444], requires_grad=True),b=Parameter containing:
# tensor([-0.0492], requires_grad=True), and loss =0.028232907876372337
# After 30 epochs, The parameters are w=Parameter containing:
# tensor([0.0443], requires_grad=True),b=Parameter containing:
# tensor([-0.0724], requires_grad=True), and loss =0.02941400557756424
# After 40 epochs, The parameters are w=Parameter containing:
# tensor([0.0447], requires_grad=True),b=Parameter containing:
# tensor([-0.0953], requires_grad=True), and loss =0.028967535123229027
# After 50 epochs, The parameters are w=Parameter containing:
# tensor([0.0450], requires_grad=True),b=Parameter containing:
# tensor([-0.1181], requires_grad=True), and loss =0.028528781607747078
# After 60 epochs, The parameters are w=Parameter containing:
# tensor([0.0454], requires_grad=True),b=Parameter containing:
# tensor([-0.1406], requires_grad=True), and loss =0.028097741305828094
# After 70 epochs, The parameters are w=Parameter containing:
# tensor([0.0457], requires_grad=True),b=Parameter containing:
# tensor([-0.1630], requires_grad=True), and loss =0.027673805132508278
# After 80 epochs, The parameters are w=Parameter containing:
# tensor([0.0461], requires_grad=True),b=Parameter containing:
# tensor([-0.1852], requires_grad=True), and loss =0.02725732885301113
# After 90 epochs, The parameters are w=Parameter containing:
# tensor([0.0464], requires_grad=True),b=Parameter containing:
# tensor([-0.2072], requires_grad=True), and loss =0.026848068460822105
# tensor(0.0118, grad_fn=<MulBackward0>)

# %%
#Q5
import torch
import numpy as np
from torch.autograd import Variable

x = Variable(torch.tensor([12.4,14.3,14.5,14.9,16.1,16.9,16.5,15.4,17.0,17.9,18.8,20.3,22.4,19.4,15.5,16.7,17.3,18.4,19.2,17.4,19.5,19.7,21.2]))
y = Variable(torch.tensor([11.2,12.5,12.7,13.1,14.1,14.8,14.4,13.4,14.9,15.6,16.4,17.7,19.6,16.9,14.0,14.6,15.1,16.1,16.8,15.2,17.0,17.2,18.6]))

class RegressionModel(torch.nn.Module):
    def __init__(self):
        super(RegressionModel, self).__init__()
        self.linear = torch.nn.Linear(23, 23)
        
    def forward(self,x):
        return self.linear(x)

model = RegressionModel()import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self,idx):
        return self.X[idx],self.Y[idx]

x = torch.tensor([1,5,10,10,25,50,70,75,100])
y = torch.tensor([0,0,0,0,0,1,1,1,1])
dataset = MyDataset(x,y)
data_loader = DataLoader(dataset,batch_size=1,shuffle=False)

class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x):
        return self.w*x + self.b

loss_fn = torch.nn.BCELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001)

for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        inputs,labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        sigmoid = torch.nn.Sigmoid()
        outputs = sigmoid(outputs)
        labels = labels.to(torch.float32)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
        loss += loss.item()

    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))

    finalloss = loss/len(data_loader)*4

print(finalloss)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr = 0.001)

for epochs in range(100):
    pred_y = model(x)
    loss = criterion(pred_y, y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if epochs%10==0:
        print("After {} epochs, loss ={}".format(epochs,loss.item()))
# Out:
#   Cell In[82], line 17
#     model = RegressionModel()import torch
#                              ^
# SyntaxError: invalid syntax

# %%
import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self,idx):
        return self.X[idx],self.Y[idx]

x = torch.tensor([5.0,7.0,12.0,16.0,20.0])
y = torch.tensor([40.0,120.0,180.0,210.0,240.0])
dataset = MyDataset(x,y)
data_loader = DataLoader(dataset,batch_size=4,shuffle=True)

for data in iter(data_loader):
    print(data)
    
learning_rate = torch.tensor(0.001)

class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x):
        return self.w*x + self.b

loss_fn = torch.nn.MSELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.003)

for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        inputs,labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
    loss += loss.item()

    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))

    finalloss = loss/len(data_loader)*4

print(finalloss)

plt.plot(loss_list)
# Out:
# [tensor([16., 20., 12.,  5.]), tensor([210., 240., 180.,  40.])]
# [tensor([7.]), tensor([120.])]
# After 0 epochs, The parameters are w=Parameter containing:
# tensor([15.2135], requires_grad=True),b=Parameter containing:
# tensor([0.9467], requires_grad=True), and loss =3846.660400390625
# After 10 epochs, The parameters are w=Parameter containing:
# tensor([14.5787], requires_grad=True),b=Parameter containing:
# tensor([1.2526], requires_grad=True), and loss =1711.43212890625
# After 20 epochs, The parameters are w=Parameter containing:
# tensor([13.0950], requires_grad=True),b=Parameter containing:
# tensor([1.4137], requires_grad=True), and loss =5.940768241882324
# After 30 epochs, The parameters are w=Parameter containing:
# tensor([14.4419], requires_grad=True),b=Parameter containing:
# tensor([1.4982], requires_grad=True), and loss =1236.9581298828125
# After 40 epochs, The parameters are w=Parameter containing:
# tensor([9.6765], requires_grad=True),b=Parameter containing:
# tensor([1.4625], requires_grad=True), and loss =2049.465087890625
# After 50 epochs, The parameters are w=Parameter containing:
# tensor([12.1923], requires_grad=True),b=Parameter containing:
# tensor([1.7659], requires_grad=True), and loss =1450.275634765625
# After 60 epochs, The parameters are w=Parameter containing:
# tensor([9.4653], requires_grad=True),b=Parameter containing:
# tensor([2.0878], requires_grad=True), and loss =2390.200439453125
# After 70 epochs, The parameters are w=Parameter containing:
# tensor([14.4896], requires_grad=True),b=Parameter containing:
# tensor([2.5521], requires_grad=True), and loss =1510.5570068359375
# After 80 epochs, The parameters are w=Parameter containing:
# tensor([13.0898], requires_grad=True),b=Parameter containing:
# tensor([2.7048], requires_grad=True), and loss =31.225688934326172
# After 90 epochs, The parameters are w=Parameter containing:
# tensor([14.4445], requires_grad=True),b=Parameter containing:
# tensor([2.9037], requires_grad=True), and loss =1674.7154541015625
# tensor(3983.9644, grad_fn=<MulBackward0>)

# %%
#Q6
import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X1,X2,Y):
        self.X1 = X1
        self.X2 = X2
        self.Y = Y
    def __len__(self):
        return len(self.X1)
    def __getitem__(self,idx):
        return self.X1[idx],self.X2[idx],self.Y[idx]

x1 = torch.tensor([3,4,5,6,2])
x2 = torch.tensor([8,5,7,3,1])
y = torch.tensor([-3.5,3.5,2.5,11.5,5.7])
dataset = MyDataset(x1,x2,y)
data_loader = DataLoader(dataset,batch_size=2,shuffle=True)

for data in iter(data_loader):
    print(data)

class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w1 = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.w2 = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x1,x2):
        return self.w1*x1 + self.w2*x2 + self.b

loss_fn = torch.nn.MSELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001)

for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        x1,x2,labels = data
        optimizer.zero_grad()
        outputs = model(x1,x2)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
    loss += loss.item()

    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w1,model.w2,model.b,loss.item()))

    finalloss = loss/len(data_loader)*4

print(finalloss)
# Out:
# [tensor([4, 2]), tensor([5, 1]), tensor([3.5000, 5.7000])]
# [tensor([3, 5]), tensor([8, 7]), tensor([-3.5000,  2.5000])]
# [tensor([6]), tensor([3]), tensor([11.5000])]
# After 0 epochs, The parameters are w=Parameter containing:
# tensor([0.5065], requires_grad=True),b=Parameter containing:
# tensor([0.4151], requires_grad=True), and loss =Parameter containing:
# tensor([0.6232], requires_grad=True)
# After 10 epochs, The parameters are w=Parameter containing:
# tensor([0.7918], requires_grad=True),b=Parameter containing:
# tensor([-0.0611], requires_grad=True), and loss =Parameter containing:
# tensor([0.6596], requires_grad=True)
# After 20 epochs, The parameters are w=Parameter containing:
# tensor([1.0555], requires_grad=True),b=Parameter containing:
# tensor([-0.3965], requires_grad=True), and loss =Parameter containing:
# tensor([0.6982], requires_grad=True)
# After 30 epochs, The parameters are w=Parameter containing:
# tensor([1.3398], requires_grad=True),b=Parameter containing:
# tensor([-0.6121], requires_grad=True), and loss =Parameter containing:
# tensor([0.7447], requires_grad=True)
# After 40 epochs, The parameters are w=Parameter containing:
# tensor([1.6105], requires_grad=True),b=Parameter containing:
# tensor([-0.7610], requires_grad=True), and loss =Parameter containing:
# tensor([0.7898], requires_grad=True)
# After 50 epochs, The parameters are w=Parameter containing:
# tensor([1.7692], requires_grad=True),b=Parameter containing:
# tensor([-0.9330], requires_grad=True), and loss =Parameter containing:
# tensor([0.8163], requires_grad=True)
# After 60 epochs, The parameters are w=Parameter containing:
# tensor([1.9032], requires_grad=True),b=Parameter containing:
# tensor([-1.0491], requires_grad=True), and loss =Parameter containing:
# tensor([0.8423], requires_grad=True)
# After 70 epochs, The parameters are w=Parameter containing:
# tensor([2.0350], requires_grad=True),b=Parameter containing:
# tensor([-1.1229], requires_grad=True), and loss =Parameter containing:
# tensor([0.8737], requires_grad=True)
# After 80 epochs, The parameters are w=Parameter containing:
# tensor([2.1260], requires_grad=True),b=Parameter containing:
# tensor([-1.1999], requires_grad=True), and loss =Parameter containing:
# tensor([0.8982], requires_grad=True)
# After 90 epochs, The parameters are w=Parameter containing:
# tensor([2.1887], requires_grad=True),b=Parameter containing:
# tensor([-1.2815], requires_grad=True), and loss =Parameter containing:
# tensor([0.9141], requires_grad=True)
# tensor(0.5874, grad_fn=<MulBackward0>)

# %%
#Q7
import torch
from torch.utils.data import Dataset,DataLoader

class MyDataset(Dataset):
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self,idx):
        return self.X[idx],self.Y[idx]

x = torch.tensor([1,5,10,10,25,50,70,75,100])
y = torch.tensor([0,0,0,0,0,1,1,1,1])
dataset = MyDataset(x,y)
data_loader = DataLoader(dataset,batch_size=1,shuffle=False)

class RegressionModel(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.w = torch.nn.Parameter(torch.rand([1],requires_grad = True))
        self.b = torch.nn.Parameter(torch.rand([1],requires_grad = True))
    def forward(self,x):
        return self.w*x + self.b

loss_fn = torch.nn.BCELoss()
model = RegressionModel()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001)

for epochs in range(100):
    loss = 0.0
    for i,data in enumerate(data_loader):
        inputs,labels = data
        optimizer.zero_grad()
        outputs = model(inputs)
        sigmoid = torch.nn.Sigmoid()
        outputs = sigmoid(outputs)
        labels = labels.to(torch.float32)
        loss = loss_fn(outputs,labels)
        loss.backward()
        optimizer.step()
        loss += loss.item()

    if epochs%10==0:
        print("After {} epochs, The parameters are w={},b={}, and loss ={}".format(epochs, model.w,model.b,loss.item()))

    finalloss = loss/len(data_loader)*4

print(finalloss)
# Out:
# After 0 epochs, The parameters are w=Parameter containing:
# tensor([0.8432], requires_grad=True),b=Parameter containing:
# tensor([0.2732], requires_grad=True), and loss =0.0
# After 10 epochs, The parameters are w=Parameter containing:
# tensor([0.5122], requires_grad=True),b=Parameter containing:
# tensor([0.2331], requires_grad=True), and loss =0.0
# After 20 epochs, The parameters are w=Parameter containing:
# tensor([0.0498], requires_grad=True),b=Parameter containing:
# tensor([0.1909], requires_grad=True), and loss =0.011994614265859127
# After 30 epochs, The parameters are w=Parameter containing:
# tensor([0.0406], requires_grad=True),b=Parameter containing:
# tensor([0.1655], requires_grad=True), and loss =0.034264951944351196
# After 40 epochs, The parameters are w=Parameter containing:
# tensor([0.0410], requires_grad=True),b=Parameter containing:
# tensor([0.1405], requires_grad=True), and loss =0.03373664990067482
# After 50 epochs, The parameters are w=Parameter containing:
# tensor([0.0414], requires_grad=True),b=Parameter containing:
# tensor([0.1158], requires_grad=True), and loss =0.03321709483861923
# After 60 epochs, The parameters are w=Parameter containing:
# tensor([0.0418], requires_grad=True),b=Parameter containing:
# tensor([0.0912], requires_grad=True), and loss =0.032706037163734436
# After 70 epochs, The parameters are w=Parameter containing:
# tensor([0.0421], requires_grad=True),b=Parameter containing:
# tensor([0.0669], requires_grad=True), and loss =0.032203830778598785
# After 80 epochs, The parameters are w=Parameter containing:
# tensor([0.0425], requires_grad=True),b=Parameter containing:
# tensor([0.0427], requires_grad=True), and loss =0.03171010687947273
# After 90 epochs, The parameters are w=Parameter containing:
# tensor([0.0429], requires_grad=True),b=Parameter containing:
# tensor([0.0188], requires_grad=True), and loss =0.03122461773455143
# tensor(0.0137, grad_fn=<MulBackward0>)
